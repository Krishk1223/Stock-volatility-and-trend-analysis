# %% [markdown]
# # Stage 2: Time Series Analysis
# ---

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

import matplotlib.pyplot as plt
import config as cf
from src.data_pipeline import plot_single_stock, plot_stocks
from src.data_pipeline import load_data, save_data
from src.time_series import features, descriptive_statistics, returns_data
from src.time_series import plot_single_log_return, plot_rolling_statistics, plot_returns_distribution, plot_annualised_volatility
from src.time_series import stock_show_plots, stock_show_acf_pacf, correlation_matrix, covariance_matrix


cleaned_data = load_data('cleaned_portfolio_data.csv')
# Out:
# Cleaned data loaded successfully.

# %% [markdown]
# ## Plotting figures:

# %%
features_df = features(cleaned_data)
features_with_stats = descriptive_statistics(features_df)
all_stocks_fig = plot_stocks(features_with_stats)
plt.show(all_stocks_fig)

# %% [markdown]
# ### AMD plots
#
# Below we see 8 plots for Advanced Micro Devices (AMD) showing the following:
#
# - Log Returns over Time (with rolling mean as well as rolling standard deviation with a window of 21 trading days)
# - Annualised (over 252 trading days within a year) Volatility Over Time
# - A histogram showcasing the distribution of the log returns overlaid with a normal distribution (to help see how skewed the tails of data are).
# - QQ plot comparing quantiles to normal distribution (helps in showing the tail behaviour)
# - ACF (autocorrelation function) of log returns data (for ARIMA justification through predicability of returns). Looking for direct + indirect effect of lags.
# - ACF (autocorrelation function) of squared log returns data (for GARCH justification through relation to volatility). Looking for direct + indirect effect of lags.
# - PACF (Partial Autocorrelation function) of log returns. Looking for direct effect of lags.
# - PACF (Partial Autocorrelation function) of squared log returns (once again for GARCH justification). Looking for direct effect of lags.

# %%
stock_choice = 'AMD'
print(f"Showing time series analysis plots for {stock_choice}...")
plt.show(stock_show_plots(features_with_stats, stock_choice))
# Out:
# Showing time series analysis plots for AMD...

# %%
print(f"Showing correlation functions for {stock_choice}...")
plt.show(stock_show_acf_pacf(features_with_stats, stock_choice))
# Out:
# Showing correlation functions for AMD...

# %% [markdown]
# ### GOOGL plots
#
# Below we see 8 plots for Google showing the following:
#
# - Log Returns over Time (with rolling mean as well as rolling standard deviation with a window of 21 trading days)
# - Annualised (over 252 trading days within a year) Volatility Over Time
# - A histogram showcasing the distribution of the log returns overlaid with a normal distribution (to help see how skewed the tails of data are).
# - QQ plot comparing quantiles to normal distribution (helps in showing the tail behaviour)
# - ACF (autocorrelation function) of log returns data (for ARIMA justification through predicability of returns). Looking for direct + indirect effect of lags.
# - ACF (autocorrelation function) of squared log returns data (for GARCH justification through relation to volatility). Looking for direct + indirect effect of lags.
# - PACF (Partial Autocorrelation function) of log returns. Looking for direct effect of lags.
# - PACF (Partial Autocorrelation function) of squared log returns (once again for GARCH justification). Looking for direct effect of lags.

# %%
stock_choice = 'GOOGL'
print(f"Showing time series analysis plots for {stock_choice}...")
plt.show(stock_show_plots(features_with_stats, stock_choice))
# Out:
# Showing time series analysis plots for GOOGL...

# %%
print(f"Showing correlation functions for {stock_choice}...")
plt.show(stock_show_acf_pacf(features_with_stats, stock_choice))
# Out:
# Showing correlation functions for GOOGL...

# %% [markdown]
# ### JPM plots
#
# Below we see 8 plots for JPMorgan showing the following:
#
# - Log Returns over Time (with rolling mean as well as rolling standard deviation with a window of 21 trading days)
# - Annualised (over 252 trading days within a year) Volatility Over Time
# - A histogram showcasing the distribution of the log returns overlaid with a normal distribution (to help see how skewed the tails of data are).
# - QQ plot comparing quantiles to normal distribution (helps in showing the tail behaviour)
# - ACF (autocorrelation function) of log returns data (for ARIMA justification through predicability of returns). Looking for direct + indirect effect of lags.
# - ACF (autocorrelation function) of squared log returns data (for GARCH justification through relation to volatility). Looking for direct + indirect effect of lags.
# - PACF (Partial Autocorrelation function) of log returns. Looking for direct effect of lags.
# - PACF (Partial Autocorrelation function) of squared log returns (once again for GARCH justification). Looking for direct effect of lags.

# %%
stock_choice = 'JPM'
print(f"Showing time series analysis plots for {stock_choice}...")
plt.show(stock_show_plots(features_with_stats, stock_choice))
# Out:
# Showing time series analysis plots for JPM...

# %%
print(f"Showing correlation functions for {stock_choice}...")
plt.show(stock_show_acf_pacf(features_with_stats, stock_choice))
# Out:
# Showing correlation functions for JPM...

# %% [markdown]
# ### XOM plots
#
# Below we see 8 plots for Exxon Mobil showing the following:
#
# - Log Returns over Time (with rolling mean as well as rolling standard deviation with a window of 21 trading days)
# - Annualised (over 252 trading days within a year) Volatility Over Time
# - A histogram showcasing the distribution of the log returns overlaid with a normal distribution (to help see how skewed the tails of data are).
# - QQ plot comparing quantiles to normal distribution (helps in showing the tail behaviour)
# - ACF (autocorrelation function) of log returns data (for ARIMA justification through predicability of returns). Looking for direct + indirect effect of lags.
# - ACF (autocorrelation function) of squared log returns data (for GARCH justification through relation to volatility). Looking for direct + indirect effect of lags.
# - PACF (Partial Autocorrelation function) of log returns. Looking for direct effect of lags.
# - PACF (Partial Autocorrelation function) of squared log returns (once again for GARCH justification). Looking for direct effect of lags.

# %%
stock_choice = 'XOM'
print(f"Showing time series analysis plots for {stock_choice}...")
plt.show(stock_show_plots(features_with_stats, stock_choice))
# Out:
# Showing time series analysis plots for XOM...

# %%
print(f"Showing correlation functions for {stock_choice}...")
plt.show(stock_show_acf_pacf(features_with_stats, stock_choice))
# Out:
# Showing correlation functions for XOM...

# %% [markdown]
# ### KO plots
#
# Below we see 8 plots for The Coca-Cola Company showing the following:
#
# - Log Returns over Time (with rolling mean as well as rolling standard deviation with a window of 21 trading days)
# - Annualised (over 252 trading days within a year) Volatility Over Time
# - A histogram showcasing the distribution of the log returns overlaid with a normal distribution (to help see how skewed the tails of data are).
# - QQ plot comparing quantiles to normal distribution (helps in showing the tail behaviour)
# - ACF (autocorrelation function) of log returns data (for ARIMA justification through predicability of returns). Looking for direct + indirect effect of lags.
# - ACF (autocorrelation function) of squared log returns data (for GARCH justification through relation to volatility). Looking for direct + indirect effect of lags.
# - PACF (Partial Autocorrelation function) of log returns. Looking for direct effect of lags.
# - PACF (Partial Autocorrelation function) of squared log returns (once again for GARCH justification). Looking for direct effect of lags.

# %%
stock_choice = 'KO'
print(f"Showing time series analysis plots for {stock_choice}...")
plt.show(stock_show_plots(features_with_stats, stock_choice))
# Out:
# Showing time series analysis plots for KO...

# %%
print(f"Showing correlation functions for {stock_choice}...")
plt.show(stock_show_acf_pacf(features_with_stats, stock_choice))
# Out:
# Showing correlation functions for KO...

# %% [markdown]
# ## Correlation and Covariance Matrix of Log Returns from the data
#
# - Correlation Matrix: Helps understand the diversity of the portfolio.
# - Covariance Matrix: Helps understand movement of multiple stocks.

# %%
print("Correlation Matrix between stocks:")
plt.show(correlation_matrix(features_with_stats))
print("Covariance Matrix between stocks:")
plt.show(covariance_matrix(features_with_stats))
# Out:
# Correlation Matrix between stocks:
# Covariance Matrix between stocks:

# %% [markdown]
# ## General Conclusions based on data (not stock specific):
#
# - Prices are non stationary (log returns are a better approach here)
# - Log returns fluctuate around zero (no persistent drift, implying not able to meaningfully predict mean).
# - Rolling Volatility varies with time (constant volatility cannot be assumed).
# - ACF and PACF of log returns are close to zero across lags (markets around 2020 were hectic due to pandemic so major fluctuations there), therefore the returns are not easily predictable (zero mean and finite variance indicative of white noise). No signal structure makes it less likely to choose ARIMA models.
# - ACF and PACF of squared log returns show positive autocorrelation with decay implying that variance is time-dependent (heteroskedasticity implied, GARCH models may be justified).
# - Returns bear fatter tails (see QQ plots) implying log returns are not normally distributed (underestimating extremes). Maybe see other distributions like student-t distribution.
# - Correlation is present between assets (AMD and Google are prime examples with a 0.53 correlation), must model joint behaviour (covariance matrix needed).
#
# As such given returns remain approximately uncorrelated but volatility is time varying and that assets bear correlation the choice of model + simulation will be as follows:
#
# - GARCH (Generalised AutoRegressive Conditional Heteroskedasticity) models, possibly GARCH(1,1 where variance at time depends on day before's squared residual + predicted variance).
# - ARIMA (AutoRegressive Integrated Moving Average) model can be used for comparison to GARCH.
# - Monte Carlo Simulations (with both normal and student t distribution)

# %% [markdown]
# ## Cleaning + Saving data for modelling
#
# - Creates a dataframe that only contains log returns data.
# - Saves to a CSV

# %%
returns_df = returns_data(features_with_stats)
save_data(returns_df, print_path=False,filename='log_returns_data.csv')
# Out:
# Cleaned data for stocks ['AMD', 'GOOGL', 'JPM', 'XOM', 'KO'] saved successfully.
